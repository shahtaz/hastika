# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # test env

# %%
import sys
import platform
import torch


print("HASTIKA ENVIRONMENT CHECK")



print(f"Python version : {platform.python_version()}")
print(f"Python path    : {sys.executable}")

print(f"\nPyTorch version: {torch.__version__}")

print(f"CUDA available : {torch.cuda.is_available()}")
print(f"CUDA version   : {torch.version.cuda}")

if torch.cuda.is_available():
    print(f"GPU            : {torch.cuda.get_device_name(0)}")
    print(f"GPU count      : {torch.cuda.device_count()}")
else:
    print("GPU            : Not available")
# Out:
# HASTIKA ENVIRONMENT CHECK
# Python version : 3.11.9
# Python path    : S:\4.2\bangla\Hastika-ICON2026\.venv\Scripts\python.exe
#
# PyTorch version: 2.11.0+cu128
# CUDA available : True
# CUDA version   : 12.8
# GPU            : NVIDIA GeForce RTX 3050 Laptop GPU
# GPU count      : 1

# %% [markdown]
# # load dataset

# %%
# load the dataset


import pandas as pd
from pathlib import Path

DATA_DIR = Path("data")

# for the task A 
binary_train = pd.read_csv(DATA_DIR / "binary_train.csv")
binary_val = pd.read_csv(DATA_DIR / "binary_validation_inputs.csv")

# task b 
multiclass_train = pd.read_csv(DATA_DIR / "multiclass_train.csv")
multiclass_val = pd.read_csv(DATA_DIR / "multiclass_validation_inputs.csv")

print("Datasets loaded successfully!")
# Out:
# Datasets loaded successfully!

# %%
# check the data set

print("Binary Training Data      :", binary_train.shape)
print("Binary Validation Data    :", binary_val.shape)
print("Multiclass Training Data  :", multiclass_train.shape)
print("Multiclass Validation Data:", multiclass_val.shape)
# Out:
# Binary Training Data      : (6446, 3)
# Binary Validation Data    : (806, 2)
# Multiclass Training Data  : (3159, 3)
# Multiclass Validation Data: (395, 2)

# %%
print("TASK A — Binary Training")
display(binary_train.head())

print("\nTASK B — Multiclass Training")
display(multiclass_train.head())
# Out:
# TASK A — Binary Training
#      id                                            Comment     Label
# 0  7417  Mir.Amarprasad nimage dhairya iddalli Sri raji...  Non-Hate
# 1  1549  amar sir , à²à³à²¹à³à²²à²¿ Bad performance,...  Non-Hate
# 2  5944  yarige bekittu inthadella avar hatra en ide bo...      Hate
# 3  7700  Ara hu cha evanu aa taliban mmaat keli illi ba...      Hate
# 4  1293      Enu boss bartha bartha hero kale kami agthide      Hate
# TASK B — Multiclass Training
#      id                                            Comment Hate Category
# 0   958  Bajetigu odalikke takarau maduvashtu vyavadana...     Political
# 1  4693  Unnata shikshana sachivanaagi Tippu bagge apap...     Political
# 2  2194  Ivlu papa avr ammage respect kodalla inn mugit...        Gender
# 3  3073  Nin english illi yeno ankonde adre big boss al...        Gender
# 4  1801  intha ugrarannu support maduva namma kelavobba...      Violence

# %%
print("Binary train columns     :", binary_train.columns.tolist())
print("Binary validation columns:", binary_val.columns.tolist())
print("Multiclass train columns :", multiclass_train.columns.tolist())
print("Multiclass validation    :", multiclass_val.columns.tolist())
# Out:
# Binary train columns     : ['id', 'Comment', 'Label']
# Binary validation columns: ['id', 'Comment']
# Multiclass train columns : ['id', 'Comment', 'Hate Category']
# Multiclass validation    : ['id', 'Comment']

# %% [markdown]
# # check the text encoding

# %%
import pandas as pd
import re

def check_text_encoding(df, text_col="Comment", sample_size=10):
    texts = df[text_col].dropna().astype(str)

    # Common signs of UTF-8 decoded incorrectly as Latin-1/Windows-1252
    mojibake_pattern = re.compile(r"(à[^\s]{0,3}|â[^\s]{0,3}|ð[^\s]{0,3}|Ã[^\s]{0,3})")

    mojibake_count = 0
    replacement_count = 0
    kannada_count = 0
    non_ascii_count = 0

    for text in texts:
        if mojibake_pattern.search(text):
            mojibake_count += 1

        if "\ufffd" in text:
            replacement_count += 1

        if any("\u0c80" <= c <= "\u0cff" for c in text):
            kannada_count += 1

        if any(ord(c) > 127 for c in text):
            non_ascii_count += 1

    print("=" * 60)
    print("TEXT ENCODING CHECK")
    print("=" * 60)

    print(f"Total comments checked : {len(texts):,}")
    print(f"Non-ASCII comments     : {non_ascii_count:,}")
    print(f"Kannada comments       : {kannada_count:,}")
    print(f"Mojibake detected      : {mojibake_count:,}")
    print(f"Replacement chars (?)  : {replacement_count:,}")

    print("\n--- Sample comments ---")

    for i, text in enumerate(texts.head(sample_size)):
        print(f"\n[{i}] {text}")

    print("\n--- Encoding diagnosis ---")

    if replacement_count > 0:
        print("Replacement characters (?) detected.")
        print("Some characters may already be irreversibly corrupted.")

    elif mojibake_count > 0:
        print("POSSIBLE ENCODING PROBLEM DETECTED.")
        print("Patterns such as 'à²', 'à³', 'Ã', 'â' or 'ð' were found.")
        print("This commonly indicates UTF-8 text decoded using the wrong encoding.")

    elif kannada_count > 0:
        print("Kannada Unicode characters detected correctly.")
        print("No obvious mojibake pattern detected.")

    else:
        print("No Kannada Unicode characters detected in the sample.")
        print("The dataset may contain mostly Romanized Kannada/English.")

    print("=" * 60)


# Task A
print("TASK A")
check_text_encoding(binary_train)

# Task B
print("\nTASK B")
check_text_encoding(multiclass_train)
# Out:
# TASK A
# ============================================================
# TEXT ENCODING CHECK
# ============================================================
# Total comments checked : 6,446
# Non-ASCII comments     : 1,016
# Kannada comments       : 0
# Mojibake detected      : 1,003
# Replacement chars (?)  : 0
#
# --- Sample comments ---
#
# [0] Mir.Amarprasad nimage dhairya iddalli Sri rajiv dixit ravara kurithagi ondu video madi
#
# [1] amar sir , à²à³à²¹à³à²²à²¿ Bad performance, eshto world best players à²¨ Best performance.<br> &quot; Level of KING KOHLI ðª
#
# [2] yarige bekittu inthadella avar hatra en ide bomb irbek ashte
#
# [3] Ara hu cha evanu aa taliban mmaat keli illi banidane
#
# [4] Enu boss bartha bartha hero kale kami agthide
#
# [5] Chaple thagond hodire e sulle ge
#
# [6] Ninu antavle bidu. Tayianthe maglu. Honnayakanahalli li ninu dodda dagar antha modle elargu gothu
#
# [7] Le dummi anchor batte bichi torsodu sadane na..
#
# [8] Dagar mundevu
#
# [9] Avana name haenu antha ghotthaglilla avani sulae maga avara Amma nijavagalu ibbanae appa Amma Hilla aa qurel man  beverci alkat thoo avana mukakkae yava partiyavaru  avanannu galligae haerislilva
#
# --- Encoding diagnosis ---
# POSSIBLE ENCODING PROBLEM DETECTED.
# Patterns such as 'à²', 'à³', 'Ã', 'â' or 'ð' were found.
# This commonly indicates UTF-8 text decoded using the wrong encoding.
# ============================================================
#
# TASK B
# ============================================================
# TEXT ENCODING CHECK
# ============================================================
# Total comments checked : 3,159
# Non-ASCII comments     : 227
# Kannada comments       : 0
# Mojibake detected      : 213
# Replacement chars (?)  : 0
#
# --- Sample comments ---
#
# [0] Bajetigu odalikke takarau maduvashtu vyavadanasiddannaellava purtikeli aAmele nimmadu eddeedeyalla avasarayake nivu bandare  tidddarayitu
#
# [1] Unnata shikshana sachivanaagi Tippu bagge apaprachaara madtanalri bhosudimaga..ivnu pakkad maneyevarige. Huttidaunu.
#
# [2] Ivlu papa avr ammage respect kodalla inn mugit film ge bandre tu ivl janmakke
#
# [3] Nin english illi yeno ankonde adre big boss alli gotaytu nin baaaaluð¤£ð¤£
#
# [4] intha ugrarannu support maduva namma kelavobba rajakarani galannu buda didnda udees madabeku
#
# [5] Le halaala hutida sule magane ninu bharat dli hutidiya aadre yudo mula nina amma na repe madi hutida papi kusu ninu
#
# [6] E kitthodhavlige acting ali navarasagala bagge ne gothila allodhu anthe comedy overacting ishte new acting skills kelkoli akka athra acting kalirii thuuu nin janmakke modhlu acting andhre enu antha thilko thuuu ??????
#
# [7] Dagar bayalli kannada beda
#
# [8] Husulimaga
#
# [9] kushi nijja ninna bhala olee avalu ankodidde Kane ishtu kettola ninu papa siddarth miss sir
#
# --- Encoding diagnosis ---
# POSSIBLE ENCODING PROBLEM DETECTED.
# Patterns such as 'à²', 'à³', 'Ã', 'â' or 'ð' were found.
# This commonly indicates UTF-8 text decoded using the wrong encoding.
# ============================================================

# %%
def fix_mojibake(text):
    try:
        return text.encode("latin1").decode("utf-8")
    except (UnicodeEncodeError, UnicodeDecodeError):
        return text


# Test on a few affected comments
for i in [1, 3, 7]:
    original = binary_train.loc[i, "Comment"]
    fixed = fix_mojibake(original)

    print("=" * 70)
    print("ORIGINAL:")
    print(original)
    print("\nFIXED:")
    print(fixed)
# Out:
# ======================================================================
# ORIGINAL:
# amar sir , à²à³à²¹à³à²²à²¿ Bad performance, eshto world best players à²¨ Best performance.<br> &quot; Level of KING KOHLI ðª
#
# FIXED:
# amar sir , ಕೊಹ್ಲಿ Bad performance, eshto world best players ನ Best performance.<br> &quot; Level of KING KOHLI 💪
# ======================================================================
# ORIGINAL:
# Ara hu cha evanu aa taliban mmaat keli illi banidane
#
# FIXED:
# Ara hu cha evanu aa taliban mmaat keli illi banidane
# ======================================================================
# ORIGINAL:
# Le dummi anchor batte bichi torsodu sadane na..
#
# FIXED:
# Le dummi anchor batte bichi torsodu sadane na..

# %%
def fix_mojibake(text):
    try:
        return text.encode("latin1").decode("utf-8")
    except (UnicodeEncodeError, UnicodeDecodeError):
        return text


# Create corrected text columns
binary_train["Comment_clean"] = binary_train["Comment"].apply(fix_mojibake)
binary_val["Comment_clean"] = binary_val["Comment"].apply(fix_mojibake)

multiclass_train["Comment_clean"] = multiclass_train["Comment"].apply(fix_mojibake)
multiclass_val["Comment_clean"] = multiclass_val["Comment"].apply(fix_mojibake)

print("Encoding correction completed.")
# Out:
# Encoding correction completed.

# %%
def encoding_summary(df, name):
    original_mojibake = df["Comment"].astype(str).str.contains(
        r"à|â|ð|Ã", regex=True
    ).sum()

    cleaned_kannada = df["Comment_clean"].astype(str).apply(
        lambda x: any("\u0c80" <= c <= "\u0cff" for c in x)
    ).sum()

    print("=" * 60)
    print(name)
    print("=" * 60)
    print(f"Rows                    : {len(df):,}")
    print(f"Original mojibake       : {original_mojibake:,}")
    print(f"Cleaned Kannada text    : {cleaned_kannada:,}")


encoding_summary(binary_train, "Binary Training")
encoding_summary(binary_val, "Binary Validation")
encoding_summary(multiclass_train, "Multiclass Training")
encoding_summary(multiclass_val, "Multiclass Validation")
# Out:
# ============================================================
# Binary Training
# ============================================================
# Rows                    : 6,446
# Original mojibake       : 1,003
# Cleaned Kannada text    : 45
# ============================================================
# Binary Validation
# ============================================================
# Rows                    : 806
# Original mojibake       : 138
# Cleaned Kannada text    : 4
# ============================================================
# Multiclass Training
# ============================================================
# Rows                    : 3,159
# Original mojibake       : 213
# Cleaned Kannada text    : 4
# ============================================================
# Multiclass Validation
# ============================================================
# Rows                    : 395
# Original mojibake       : 22
# Cleaned Kannada text    : 2

# %%
print("\nSample corrected comments:\n")

for i in range(10):
    if binary_train.loc[i, "Comment"] != binary_train.loc[i, "Comment_clean"]:
        print("ORIGINAL:")
        print(binary_train.loc[i, "Comment"])
        print("\nCORRECTED:")
        print(binary_train.loc[i, "Comment_clean"])
        print("\n" + "-" * 70)
# Out:
# Sample corrected comments:
#
# ORIGINAL:
# amar sir , à²à³à²¹à³à²²à²¿ Bad performance, eshto world best players à²¨ Best performance.<br> &quot; Level of KING KOHLI ðª
#
# CORRECTED:
# amar sir , ಕೊಹ್ಲಿ Bad performance, eshto world best players ನ Best performance.<br> &quot; Level of KING KOHLI 💪
#
# ----------------------------------------------------------------------

# %% [markdown]
# # data inspection

# %%
# Dataset quality inspection

datasets = {
    "Binary Train": binary_train,
    "Binary Validation": binary_val,
    "Multiclass Train": multiclass_train,
    "Multiclass Validation": multiclass_val
}

for name, df in datasets.items():
    print("=" * 70)
    print(name)
    print("=" * 70)

    print("Shape:", df.shape)

    print("\nMissing values:")
    print(df.isnull().sum())

    print("\nDuplicate rows:", df.duplicated().sum())
    print("Duplicate comments:", df["Comment_clean"].duplicated().sum())

    if "Label" in df.columns:
        print("\nLabels:")
        print(df["Label"].value_counts())

    if "Hate Category" in df.columns:
        print("\nHate Categories:")
        print(df["Hate Category"].value_counts())

    print()
# Out:
# ======================================================================
# Binary Train
# ======================================================================
# Shape: (6446, 4)
#
# Missing values:
# id               0
# Comment          0
# Label            0
# Comment_clean    0
# dtype: int64
#
# Duplicate rows: 0
# Duplicate comments: 37
#
# Labels:
# Label
# Non-Hate    3286
# Hate        3160
# Name: count, dtype: int64
#
# ======================================================================
# Binary Validation
# ======================================================================
# Shape: (806, 3)
#
# Missing values:
# id               0
# Comment          0
# Comment_clean    0
# dtype: int64
#
# Duplicate rows: 0
# Duplicate comments: 0
#
# ======================================================================
# Multiclass Train
# ======================================================================
# Shape: (3159, 4)
#
# Missing values:
# id               0
# Comment          0
# Hate Category    0
# Comment_clean    0
# dtype: int64
#
# Duplicate rows: 0
# Duplicate comments: 13
#
# Hate Categories:
# Hate Category
# Gender           1362
# Political         559
# Others            449
# Religion          382
# Violence          221
# Geo-political     186
# Name: count, dtype: int64
#
# ======================================================================
# Multiclass Validation
# ======================================================================
# Shape: (395, 3)
#
# Missing values:
# id               0
# Comment          0
# Comment_clean    0
# dtype: int64
#
# Duplicate rows: 0
# Duplicate comments: 0

# %%
import matplotlib.pyplot as plt

# Task A
plt.figure(figsize=(7, 5))
binary_train["Label"].value_counts().plot(kind="bar")
plt.title("Task A - Hate vs Non-Hate")
plt.xlabel("Label")
plt.ylabel("Number of Comments")
plt.xticks(rotation=0)
plt.show()


# Task B
plt.figure(figsize=(9, 5))
multiclass_train["Hate Category"].value_counts().plot(kind="bar")
plt.title("Task B - Hate Category Distribution")
plt.xlabel("Hate Category")
plt.ylabel("Number of Comments")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # comment length analysis & preprocessing

# %%
# Comment length analysis

for df in [binary_train, multiclass_train]:
    df["char_length"] = df["Comment_clean"].str.len()
    df["word_count"] = df["Comment_clean"].str.split().str.len()


print("=" * 60)
print("TASK A - BINARY TRAIN")
print("=" * 60)

print(binary_train[["char_length", "word_count"]].describe())


print("\n" + "=" * 60)
print("TASK B - MULTICLASS TRAIN")
print("=" * 60)

print(multiclass_train[["char_length", "word_count"]].describe())
# Out:
# ============================================================
# TASK A - BINARY TRAIN
# ============================================================
#        char_length   word_count
# count  6446.000000  6446.000000
# mean     74.725411    11.095098
# std      76.173411    10.757534
# min       5.000000     1.000000
# 25%      32.000000     5.000000
# 50%      52.000000     8.000000
# 75%      89.000000    13.000000
# max    1084.000000   136.000000
#
# ============================================================
# TASK B - MULTICLASS TRAIN
# ============================================================
#        char_length   word_count
# count  3159.000000  3159.000000
# mean     87.047800    12.714783
# std      82.622162    11.688077
# min       7.000000     1.000000
# 25%      38.000000     6.000000
# 50%      61.000000     9.000000
# 75%     106.000000    15.000000
# max     875.000000   128.000000

# %%
# Character length distribution

plt.figure(figsize=(10, 5))
plt.hist(binary_train["char_length"], bins=50)
plt.title("Task A - Comment Character Length")
plt.xlabel("Number of Characters")
plt.ylabel("Number of Comments")
plt.show()


# Word count distribution

plt.figure(figsize=(10, 5))
plt.hist(binary_train["word_count"], bins=50)
plt.title("Task A - Comment Word Count")
plt.xlabel("Number of Words")
plt.ylabel("Number of Comments")
plt.show()

# %%
# Check duplicate comments and their labels

print("=" * 70)
print("TASK A - DUPLICATE COMMENTS")
print("=" * 70)

duplicates_a = binary_train[
    binary_train["Comment_clean"].duplicated(keep=False)
].sort_values("Comment_clean")

display(duplicates_a[["Comment_clean", "Label"]])


print("\n" + "=" * 70)
print("TASK B - DUPLICATE COMMENTS")
print("=" * 70)

duplicates_b = multiclass_train[
    multiclass_train["Comment_clean"].duplicated(keep=False)
].sort_values("Comment_clean")

display(duplicates_b[["Comment_clean", "Hate Category"]])
# Out:
# ======================================================================
# TASK A - DUPLICATE COMMENTS
# ======================================================================
#                                           Comment_clean     Label
# 4636                         nim moun tulla randi magan      Hate
# 6149                         nim moun tulla randi magan      Hate
# 2985                       700 koti rajyada papulation?  Non-Hate
# 5179                       700 koti rajyada papulation?  Non-Hate
# 4158  A hengadina miukha didare nachike agutte  nama...      Hate
# ...                                                 ...       ...
# 2806  Swami , avaga yav govt ittu annodu heltiyalla....      Hate
# 2191                 Yenne Congress Party Muduka😂😂😂😂😂😂👍      Hate
# 4390                 Yenne Congress Party Muduka😂😂😂😂😂😂👍      Hate
# 5377  yena.rajakarnigalu..YEKVACHANADLI.MATHDTHI...A...      Hate
# 5555  yena.rajakarnigalu..YEKVACHANADLI.MATHDTHI...A...      Hate
#
# [69 rows x 2 columns]
# ======================================================================
# TASK B - DUPLICATE COMMENTS
# ======================================================================
#                                           Comment_clean  Hate Category
# 1631                         nim moun tulla randi magan         Gender
# 1751                         nim moun tulla randi magan         Gender
# 396                        Boli Maga na ninu csk fan na         Gender
# 1001                       Boli Maga na ninu csk fan na         Gender
# 243             Dagar dagar dam dam dagar dagar sule ??         Gender
# 2636            Dagar dagar dam dam dagar dagar sule ??         Gender
# 1123                                         Dagar sonu         Gender
# 1135                                         Dagar sonu         Gender
# 2972                                         Dagar sonu         Gender
# 1801  Ivane dodda kala ivanu hatra hogi question kel...         Others
# 2516  Ivane dodda kala ivanu hatra hogi question kel...         Others
# 908   Nina.meravange.madidarll.Ninenu.helodu..ninaha...      Political
# 1783  Nina.meravange.madidarll.Ninenu.helodu..ninaha...      Political
# 582   Ninuna jilige hakidre desha rajyake nemdi     ...  Geo-political
# 2287  Ninuna jilige hakidre desha rajyake nemdi     ...      Political
# 1046            ROUDY,HADISIMAGA,D,K,BRASHTA,E,BOLEMAGA         Gender
# 3117            ROUDY,HADISIMAGA,D,K,BRASHTA,E,BOLEMAGA         Gender
# 975                                   Sonu gowda mindri         Gender
# 1413                                  Sonu gowda mindri         Gender
# 971                                          Sule munde         Gender
# 1242                                         Sule munde         Gender
# 108   Surprise enuo ellappa edhella namma janru madk...  Geo-political
# 248   Surprise enuo ellappa edhella namma janru madk...         Others
# 698   yena.rajakarnigalu..YEKVACHANADLI.MATHDTHI...A...      Political
# 1639  yena.rajakarnigalu..YEKVACHANADLI.MATHDTHI...A...      Political

# %%
# Find duplicate comments with conflicting labels/categories

print("=" * 70)
print("TASK A - CONFLICTING DUPLICATES")
print("=" * 70)

conflicts_a = (
    binary_train.groupby("Comment_clean")["Label"]
    .nunique()
)

conflicts_a = conflicts_a[conflicts_a > 1]

print("Number of conflicting comments:", len(conflicts_a))


print("\n" + "=" * 70)
print("TASK B - CONFLICTING DUPLICATES")
print("=" * 70)

conflicts_b = (
    multiclass_train.groupby("Comment_clean")["Hate Category"]
    .nunique()
)

conflicts_b = conflicts_b[conflicts_b > 1]

print("Number of conflicting comments:", len(conflicts_b))
# Out:
# ======================================================================
# TASK A - CONFLICTING DUPLICATES
# ======================================================================
# Number of conflicting comments: 3
#
# ======================================================================
# TASK B - CONFLICTING DUPLICATES
# ======================================================================
# Number of conflicting comments: 2

# %%
# Display all conflicting duplicate comments

print("=" * 70)
print("TASK A - CONFLICTING DUPLICATES")
print("=" * 70)

conflict_comments_a = (
    binary_train.groupby("Comment_clean")["Label"]
    .nunique()
)

conflict_comments_a = conflict_comments_a[
    conflict_comments_a > 1
].index

display(
    binary_train[
        binary_train["Comment_clean"].isin(conflict_comments_a)
    ][["Comment_clean", "Label"]]
    .sort_values("Comment_clean")
)


print("\n" + "=" * 70)
print("TASK B - CONFLICTING DUPLICATES")
print("=" * 70)

conflict_comments_b = (
    multiclass_train.groupby("Comment_clean")["Hate Category"]
    .nunique()
)

conflict_comments_b = conflict_comments_b[
    conflict_comments_b > 1
].index

display(
    multiclass_train[
        multiclass_train["Comment_clean"].isin(conflict_comments_b)
    ][["Comment_clean", "Hate Category"]]
    .sort_values("Comment_clean")
)
# Out:
# ======================================================================
# TASK A - CONFLICTING DUPLICATES
# ======================================================================
#                                           Comment_clean     Label
# 5924        Ella cm thara evaru adjust aagilla adkke...      Hate
# 5970        Ella cm thara evaru adjust aagilla adkke...  Non-Hate
# 184   Ivanu jail inda bandaga en madidda gottillva n...      Hate
# 2644  Ivanu jail inda bandaga en madidda gottillva n...  Non-Hate
# 1124  Kangres gorment barbeku sidramyyasar cmagbeku ...      Hate
# 4121  Kangres gorment barbeku sidramyyasar cmagbeku ...  Non-Hate
# ======================================================================
# TASK B - CONFLICTING DUPLICATES
# ======================================================================
#                                           Comment_clean  Hate Category
# 582   Ninuna jilige hakidre desha rajyake nemdi     ...  Geo-political
# 2287  Ninuna jilige hakidre desha rajyake nemdi     ...      Political
# 108   Surprise enuo ellappa edhella namma janru madk...  Geo-political
# 248   Surprise enuo ellappa edhella namma janru madk...         Others

# %%
# Sample comments from each Task A class

print("=" * 70)
print("TASK A - SAMPLE COMMENTS")
print("=" * 70)

for label in ["Hate", "Non-Hate"]:
    print("\n" + "-" * 70)
    print(label)
    print("-" * 70)

    samples = binary_train[
        binary_train["Label"] == label
    ]["Comment_clean"].sample(
        n=10,
        random_state=42
    )

    for i, comment in enumerate(samples, 1):
        print(f"{i}. {comment}")
# Out:
# ======================================================================
# TASK A - SAMPLE COMMENTS
# ======================================================================
#
# ----------------------------------------------------------------------
# Hate
# ----------------------------------------------------------------------
# 1. Entha avurunu yaru interview madala
# 2. @Seenu N le appi hogi maneli amma yendru madirthare tindubittu uchhe uyyidubittu malko ogu aste nin jeevana😂
# 3. Leee bevarsi nimkinta aa madrasi gale eshto vasi
# 4. Innentha math adtare nim antha backet hidkond views goskara thu nim makke
# 5. Innenu Intha kitthodhor na akondre disrespect bittre innen expect madthira? Ah ibbru lowdas name gothilla.. short hair girl and curly hair guy noduddhre mai mai mutkondu asayyadh chutiyas thara adthare. This is freaking family show where public audiences expects friendship, respect and manners. But this ott has none of these. Tv news chutiyagalge olle TRP and useless content. SUDEEP SIR ANTHU SONU GE CHAPPALI LI ODDHANG HELUDDHRU AVL MOKA NAYI HEL THINDHIRO THARA AGIDHE 😂🔥
# 6. Sule inu eshtu janaranna kondidalo
# 7. Nehru the true villan of the Kashmir problems pandits hesaru helkkondu mosa madida deshakke.. Sins of Nehru, indira Gandhi and Rajiv Gandhi ella vapas bantu in the same way of terrorism. God punished Nehru family for their dwesha hindu gala jotege.
# 8. En kittavle anta nen interview madtidiya thooo nim janmakke
# 9. Aa Kitthodh mundege Chappali thagondu hakodu bittu yaaru madde iro thappu avlenu madilla antha helthyalla Avl Para ne mathadthyalla Thayi neenu????
# 10. Ittralla nimge saryagi..Bjp avru bari build 😂up amel clean sweep...😂😂😂Aaytu😂😂😅😅😅
#
# ----------------------------------------------------------------------
# Non-Hate
# ----------------------------------------------------------------------
# 1. Intavrinda desha haalaagtirodu.stop fantasizing babar,akbar,tippu. Saaku nillisi.<br>Aavattu bere vidhi illa convert aadavaru ivattu naanu Islam ge huttidavnu ankondu hindu galla avahelana maadtidaare.<br>Islam illi bandiddu hege first tillkolli.<br>Dharma nimmista,aadre nimma roots tillkollodu nimma kartavya.
# 2. Bro nija yelthidhira,,  sathya,,  but hindhu Gala manasthithi badhalagbeku, naavu Shanthi priyaru,, it&#39;s our responsibility to accept others,  yarella barthare avrella namma athithigalu annidhu nija, but we should put a eye on present situations..  Chanakyana raaja neethi yenandhre prathiyondhu haaguogugala mele gamana ettirbeku aste alla, avashyakathe edhre we should take necessary actions..  We failed at 1990s.. Inmelindha ondhagbeku..  Namge thondhre bandhaga... Thumba maathadbavdhu but not a platform..  Sorry
# 3. caste based stories galu ivella
# 4. Public ge kelri opinion ena anta gottagutte
# 5. Revenge andre Revenge never underestimate king kohli😍💪💥
# 6. Controversy agli anta kaitirtira views ge
# 7. Bro gt and lsg match ninge fixing anta annisalilla adre mi match fix annustayidiya
# 8. The kashmiri files cinema kannadakke dub auttide
# 9. I don&#39;t like her, miss u SP nivu andre tumba ishta
# 10. FIR__movi review madu guru

# %%
# Sample comments from each Task B category

print("=" * 70)
print("TASK B - SAMPLE COMMENTS")
print("=" * 70)

categories = [
    "Gender",
    "Political",
    "Religion",
    "Geo-political",
    "Violence",
    "Others"
]

for category in categories:
    print("\n" + "-" * 70)
    print(category)
    print("-" * 70)

    samples = multiclass_train[
        multiclass_train["Hate Category"] == category
    ]["Comment_clean"].sample(
        n=min(10, len(multiclass_train[
            multiclass_train["Hate Category"] == category
        ])),
        random_state=42
    )

    for i, comment in enumerate(samples, 1):
        print(f"{i}. {comment}")
# Out:
# ======================================================================
# TASK B - SAMPLE COMMENTS
# ======================================================================
#
# ----------------------------------------------------------------------
# Gender
# ----------------------------------------------------------------------
# 1. Mooru bittoru urge doddoru ?? ural yar yen helidru care madalla ee dove rani????????
# 2. Mostly ee btv  sonu relative avr channel ansutte???? adeng ivlna oglutare sadane sadane anta,oo god, channel avrge maryade idiya ,en kit dabakidald aa sonu , yav seeme celebrity avlu aa
# 3. Le lowdy siddu nin Sacha sule maga
# 4. Nin amma paapa kane yake lovede nin ammange value kodo soolemunde avra yedhurgadene kaal mele haaki  kari thullu thoristha idhiyalla thuu
# 5. Ivnyaro sule maga
# 6. Sonu matadod nodudre Tika ella uriyutte olle chaild tara adtale
# 7. No 1 dagar in Asia
# 8. Sule munde nA kyakarsi hugthu hatti avla ache ge
# 9. Sania mirza muradabad ppakistani loafer lady Jai kannada jai Karnataka ivalu tulli
# 10. Dagar dagar avl???? idu bittu bere  enilla
#
# ----------------------------------------------------------------------
# Political
# ----------------------------------------------------------------------
# 1. Barri natka nimdella congress avru kas kottirbeku e yappange ð???ð???ð???ð???
# 2. Yetnal gowda Patil ge CM Madli nodi avaga turkru nava randhra galannu muchhi kondu eratare
# 3. Lokayuktha close madlilva sidda 😡
# 4. En speaker neevu enri helthidira nachike agalva full state li matter hagiro matter bagge helilla andre matadodu bedva en sir neevu
# 5. dikeshi ge enu gottu janara kashta sulemaga dkshi
# 6. Uttara Karnataka martiro e sarkarakke ugiri
# 7. BJP loot BJP drama BJP all mp mla 420 sulya makalu rowdy BJP
# 8. hindu sthan nalli muslim safe ....but <br>muslim eriea nalli iro hindu kuda safe illa....
# 9. 40% golmall govt. Jai siddu
# 10. 40%B J P THU
#
# ----------------------------------------------------------------------
# Religion
# ----------------------------------------------------------------------
# 1. @Pradeep Kumar Narayanappa Shiroorkar avarige artaagalla bidi sir..artha aagbekaadre ee charchege baruva atava brain vash maduvavana magano family ya hena beelbeku...illi hindutwa antha sayoodu only poor people ..estu helidru buddibaralla
# 2. Dayavity sabara manaege kalisi e buudana
# 3. Nimge kuda dikkara ee mullagalella seri desha haalu madtare
# 4. Hindugalu ivagaladru yechetgondila andre , nale HINDUSTAN FILES antha film bandru ascharya illa .
# 5. Avag edad BJP govt..hindu galan konsa plan madiddu BJP govt..history allu torsilla sule maklu rajkiya madirodu..eddeli hindugale nim esrall badki nimmanne kolsavre....plus 11500 muslim women&#39;s na rape Madirodu thorsilva.... Pandiths and RSS wadigalu rape Madirodu thorsavra... Avr raktha yest kuddirbardu... Godra dal 3500 muslim suttirodu thorsidara... Paapa... Kanirla 300 pandiths sathidare ade timel 1500 muslims na kondirodu thorsilva... Nim yogaytheg nan mettu...sule hindus.. Rajkiya nadsak dwesha tumbtavre.. Matte gulaam nagag desha ready agtide.. 11500 girls rape madida hindu tunne na yav riti chach beku... 15000 muslim kondirovrna yav shikshe kodbeku.. Matte siddavagali India????..... Again we are back
# 6. @#psDaridra buddiya bevarsi.  Indian president brahmana alla, PM brahmana alla, UP CM, Karnataka CM, MP CM, Andra CM, Telangana CM, TN CM, Kerala CM, Maharastra CM, Bhi ha CM, Gujrat CM, Rajastan CM, Assam CM, yayu brahmanaru alla.  Tilidu matado shata mu
# 7. Idarali muslims yake yak urkolbeku... <br>Terrorist yav dharmasavnadre yenu avnige shikshe aglebeku
# 8. avaru Khan gress pappu siddu Khan brothers
# 9. Simple this is islamic terrorism kolodakke harsh ede but uts fack IT&#39;S ISLAMIC TERRORISM....
# 10. Aababababaaaa en acting guru nindu ?? modlu hogi itihasa odhu amele ivella pungu anthe ?? Raja 30.000 alla raja 3 adu adralli vabru hindu inna ibru Christian. Views goskara cheap tricks use madbeda swalpa Ella thilkondu Ella search madi adu nija na sulla antha thilkondu amel pungu
#
# ----------------------------------------------------------------------
# Geo-political
# ----------------------------------------------------------------------
# 1. Munde magne, ade 650 ge 20 kg ragi barthade Or 15 kg rice bathade one week thinhidu. Thin munde magne.
# 2. if I can not Dnt enter Karnataka ganchali nam Anna Neeru bekku first medias Dnt promote her
# 3. 1St SLEPAR TAGOND HODADA HORGE KALSI E DARIDRA NA DAYA MADI NAMA KARANATAKA DALI E TARA SPORTS PARSON S NA YAVATHU KARI BEDI EVARU BANDRE HENU BITRE HENU BEKADASHTU SPORTS PARSON S IDARE IVLE BEKITHA PLZ REQUEST NAMA kannadigarige YAVATHU INTHA DARIDRAGALANA BITAKOBEDI
# 4. ADIKKE NAMMA KANNADA INDUSTRY IVATHU NAALAYAK AGIRODHU😂😂😂😂😂😂😂<br>YAARU MOOSU NODTHA ILLA...<br><br>JAI KARNATAKA...
# 5. Pakistan hogi kogu dikarana
# 6. So called Bhikaatigalu 10 kg Akki ge Baliyagbardu , Adrallo benglurigalu  secularigalige vote haakbardu modiji kodu Akkige Tamma Lebell Antisi Naau kotteu antha  Bogalu bhattrige ban  madi
# 7. Kannada maryade thegyodu saniya dagar alla kannada news channel avru...Sikka sikkavrathra hogi kannada mathadi plzzzzz kannada mathadi plzzzzz sir/Mam andre idhe tara answer sigodu..Kannadana avre ista pattu mathadbeku avaga kannadake ondhu respect erutthe.Evlu kannada mathadade idhre aste hoithu..Get lost saniya dagar munde.
# 8. Evanu danada mamsa tike pakistanke kalsi Alle erli mathe barode beda
# 9. Pakistan nayi hareti akige hanga maduda ada
# 10. Saniyage Pakistanake kalisbeku avalu deshadroyi
#
# ----------------------------------------------------------------------
# Violence
# ----------------------------------------------------------------------
# 1. underworld don muttappa Rai du party ante guru
# 2. I'm Indian Muslim sir nange weapons kodi naan pakistanakke hogi avara 400 janarannu bomb haki koltene..... Naan sathru paravagilla
# 3. raja Hari Singh madiddrinda ishtella agtirodu avanna bandhisbekittu
# 4. Vikruta manassina Terrorists madiro karanakke: ella Muslims galanna target madtidare: navu elle huttidivi elle saytivi we are indians
# 5. Pappa Harish na namind kitakonda   biteyalle kolegarti
# 6. Ondu kelsa madana aunu yalle erli tandu kochi kochi charga madi bisasana
# 7. Avna modalu roadalli suttakape
# 8. Bjp alli eruvavru Matra hindu alla ... Ninge buddi bramane agide... Chappalalli ninge hodko bvc
# 9. Nan kaili gun kodi avan hutte illa anno haage madtini.
# 10. Desha drohi yavathu devaru kshmisudilla anthavaru papigalu
#
# ----------------------------------------------------------------------
# Others
# ----------------------------------------------------------------------
# 1. Oh eega sagani tinnorge cinemagalu real aage kaantive.
# 2. Parents cultured illa andre makkalu adda dari hidithare
# 3. Next week sonuna eliminate madi yaru esta padalla
# 4. Manegey  hogi bashana madu elliyenu proyojana ella
# 5. nim btv ge bere kelsa elvaa yen adru Jana ke olid agod madriiii e kithogiroooo interview takolodu bucket hidiyadu Este aithuuu tuuu ...
# 6. Mi &amp; CSK ban madi
# 7. Astorolagagale, kala meeriruttade. Neevu sayuva varegu kanneridutta koragi sayutteeri<br><br>Jai BJP, Jai Modi, Jai Bhajarangi
# 8. Evaga avrige chappali thagondu hodibardu . Karkondu bandu interview madthiddarala nimge hodi bekuu. Interview madthini andre Bekadastu sadhane madiro antha mahan dodda vyakthigalu  edare . Avaarnna bittu hogi hogi ee Dagar interview madthaediraallla nimge enu helbeku
# 9. @Deekshith Kundar prataf 😅😅 kav kav 💥😅
# 10. Etaranu interview madtare ant iga gottaitu,,,,idoddu interview na thuu

# %%
import html
import re

def clean_text(text):
    # Decode HTML entities
    text = html.unescape(text)

    # Remove HTML tags
    text = re.sub(r"<[^>]+>", " ", text)

    # Normalize whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text


binary_train["text"] = binary_train["Comment_clean"].apply(clean_text)
binary_val["text"] = binary_val["Comment_clean"].apply(clean_text)

multiclass_train["text"] = multiclass_train["Comment_clean"].apply(clean_text)
multiclass_val["text"] = multiclass_val["Comment_clean"].apply(clean_text)

print("Text cleaning completed.")
# Out:
# Text cleaning completed.

# %%
print(binary_train["text"].iloc[0])
# Out:
# Mir.Amarprasad nimage dhairya iddalli Sri rajiv dixit ravara kurithagi ondu video madi

# %%
import html
import re

def clean_text(text):
    # Decode HTML entities
    text = html.unescape(text)

    # Remove HTML tags
    text = re.sub(r"<[^>]+>", " ", text)

    # Normalize whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text


binary_train["text"] = binary_train["Comment_clean"].apply(clean_text)
binary_val["text"] = binary_val["Comment_clean"].apply(clean_text)

multiclass_train["text"] = multiclass_train["Comment_clean"].apply(clean_text)
multiclass_val["text"] = multiclass_val["Comment_clean"].apply(clean_text)

print("Text preprocessing completed.")
# Out:
# Text preprocessing completed.

# %%
print("Original:")
print(binary_train["Comment_clean"].iloc[99])

print("\nCleaned:")
print(binary_train["text"].iloc[99])
# Out:
# Original:
# Nin maglige etkond hogi covert madil alwa adke ee reeti matadtiddiya
#
# Cleaned:
# Nin maglige etkond hogi covert madil alwa adke ee reeti matadtiddiya

# %% [markdown]
# # train val split

# %%
from sklearn.model_selection import train_test_split

# ============================================================
# TASK A - BINARY CLASSIFICATION
# ============================================================

X_a = binary_train["text"]
y_a = binary_train["Label"]

X_a_train, X_a_val, y_a_train, y_a_val = train_test_split(
    X_a,
    y_a,
    test_size=0.20,
    random_state=42,
    stratify=y_a
)


# ============================================================
# TASK B - MULTICLASS CLASSIFICATION
# ============================================================

X_b = multiclass_train["text"]
y_b = multiclass_train["Hate Category"]

X_b_train, X_b_val, y_b_train, y_b_val = train_test_split(
    X_b,
    y_b,
    test_size=0.20,
    random_state=42,
    stratify=y_b
)


# ============================================================
# CHECK SPLIT SIZES
# ============================================================

print("=" * 70)
print("TASK A - BINARY")
print("=" * 70)

print("Training samples   :", len(X_a_train))
print("Validation samples :", len(X_a_val))


print("\n" + "=" * 70)
print("TASK B - MULTICLASS")
print("=" * 70)

print("Training samples   :", len(X_b_train))
print("Validation samples :", len(X_b_val))
# Out:
# ======================================================================
# TASK A - BINARY
# ======================================================================
# Training samples   : 5156
# Validation samples : 1290
#
# ======================================================================
# TASK B - MULTICLASS
# ======================================================================
# Training samples   : 2527
# Validation samples : 632

# %% [markdown]
# # task A

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# ============================================================
# TASK A - TF-IDF + LOGISTIC REGRESSION
# ============================================================

task_a_lr = Pipeline([
    ("tfidf", TfidfVectorizer(
        analyzer="word",
        ngram_range=(1, 2),
        min_df=2,
        sublinear_tf=True
    )),
    
    ("classifier", LogisticRegression(
        max_iter=1000,
        class_weight="balanced",
        random_state=42
    ))
])

# Train
task_a_lr.fit(X_a_train, y_a_train)

print("Task A baseline model trained successfully.")
# Out:
# Task A baseline model trained successfully.

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report

# ============================================================
# TASK A - BASELINE EVALUATION
# ============================================================

# Predict validation data
y_a_pred = task_a_lr.predict(X_a_val)

# Calculate metrics
accuracy = accuracy_score(y_a_val, y_a_pred)
macro_f1 = f1_score(y_a_val, y_a_pred, average="macro")

print("=" * 70)
print("TASK A - TF-IDF + LOGISTIC REGRESSION")
print("=" * 70)

print(f"Accuracy : {accuracy:.4f}")
print(f"Macro F1 : {macro_f1:.4f}")

print("\nClassification Report:")
print(classification_report(y_a_val, y_a_pred))
# Out:
# ======================================================================
# TASK A - TF-IDF + LOGISTIC REGRESSION
# ======================================================================
# Accuracy : 0.7667
# Macro F1 : 0.7665
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Hate       0.77      0.75      0.76       632
#     Non-Hate       0.77      0.78      0.77       658
#
#     accuracy                           0.77      1290
#    macro avg       0.77      0.77      0.77      1290
# weighted avg       0.77      0.77      0.77      1290

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# ============================================================
# TASK A - CHARACTER TF-IDF + LINEAR SVM
# ============================================================

task_a_char_svm = Pipeline([
    ("tfidf", TfidfVectorizer(
        analyzer="char",
        ngram_range=(3, 5),
        min_df=2,
        sublinear_tf=True
    )),
    
    ("classifier", LinearSVC(
        class_weight="balanced",
        random_state=42
    ))
])

# Train
task_a_char_svm.fit(X_a_train, y_a_train)

print("Task A Character TF-IDF + Linear SVM trained successfully.")
# Out:
# Task A Character TF-IDF + Linear SVM trained successfully.

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report

# ============================================================
# TASK A - CHARACTER TF-IDF + LINEAR SVM EVALUATION
# ============================================================

y_a_char_pred = task_a_char_svm.predict(X_a_val)

accuracy_char = accuracy_score(y_a_val, y_a_char_pred)
macro_f1_char = f1_score(y_a_val, y_a_char_pred, average="macro")

print("=" * 70)
print("TASK A - CHARACTER TF-IDF + LINEAR SVM")
print("=" * 70)

print(f"Accuracy : {accuracy_char:.4f}")
print(f"Macro F1 : {macro_f1_char:.4f}")

print("\nClassification Report:")
print(classification_report(y_a_val, y_a_char_pred))
# Out:
# ======================================================================
# TASK A - CHARACTER TF-IDF + LINEAR SVM
# ======================================================================
# Accuracy : 0.8047
# Macro F1 : 0.8043
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Hate       0.81      0.78      0.80       632
#     Non-Hate       0.80      0.83      0.81       658
#
#     accuracy                           0.80      1290
#    macro avg       0.81      0.80      0.80      1290
# weighted avg       0.81      0.80      0.80      1290

# %%
# ============================================================
# TASK A - ERROR ANALYSIS
# ============================================================

error_analysis_a = pd.DataFrame({
    "text": X_a_val,
    "actual": y_a_val,
    "predicted": y_a_char_pred
})

# False Positives
false_positives = error_analysis_a[
    (error_analysis_a["actual"] == "Non-Hate") &
    (error_analysis_a["predicted"] == "Hate")
]

# False Negatives
false_negatives = error_analysis_a[
    (error_analysis_a["actual"] == "Hate") &
    (error_analysis_a["predicted"] == "Non-Hate")
]

print("=" * 70)
print("TASK A - ERROR ANALYSIS")
print("=" * 70)

print(f"False Positives : {len(false_positives)}")
print(f"False Negatives : {len(false_negatives)}")

print("\n" + "=" * 70)
print("FALSE POSITIVES - Non-Hate predicted as Hate")
print("=" * 70)

display(false_positives[["text", "actual", "predicted"]].head(20))

print("\n" + "=" * 70)
print("FALSE NEGATIVES - Hate predicted as Non-Hate")
print("=" * 70)

display(false_negatives[["text", "actual", "predicted"]].head(20))
# Out:
# ======================================================================
# TASK A - ERROR ANALYSIS
# ======================================================================
# False Positives : 112
# False Negatives : 140
#
# ======================================================================
# FALSE POSITIVES - Non-Hate predicted as Hate
# ======================================================================
#                                                    text    actual predicted
# 1066   Innu swalpa dina Johnny sins karstare btv avru😃😃  Non-Hate      Hate
# 1724  CM avarige gotide thathaya adare stana goskara...  Non-Hate      Hate
# 2420  Super...avar lifelli nadediruvudu avrige gottu...  Non-Hate      Hate
# 4513  Anna yar adru modlu sonu na yar adru antarica ...  Non-Hate      Hate
# 5970        Ella cm thara evaru adjust aagilla adkke...  Non-Hate      Hate
# 693           Le tv 9 alle muniswamy help maadta eorodu  Non-Hate      Hate
# 4813  😂 Kohili first young players na sledge madodu ...  Non-Hate      Hate
# 4816                              Nammalli oggattu illa  Non-Hate      Hate
# 1614                        Thayige first mariyade kodu  Non-Hate      Hate
# 5070            5:06 innen madtare inta maglu uttidmele  Non-Hate      Hate
# 1445  Le meat band maadtivi anta yaaro heliddu...yel...  Non-Hate      Hate
# 2752         ivru barde iddidre ishtottige eshtu chanda  Non-Hate      Hate
# 6247  Sonu sadane anta helteralla en sadane anta hel...  Non-Hate      Hate
# 6381                        Speaker joker iddange idane  Non-Hate      Hate
# 2038    ishtella strike madiddakke enaytu anta gottalla  Non-Hate      Hate
# 5663                      Hale bevarasi megana daraidra  Non-Hate      Hate
# 1746  Karnataka nataka mandali. Mooru thandagalu... ...  Non-Hate      Hate
# 2236                        Bjp agent bosadi nann maklu  Non-Hate      Hate
# 6005  Hella ghothiddu congress win haithu yake Nan h...  Non-Hate      Hate
# 4887                  Karnataka ke BJP mokthi beku aste  Non-Hate      Hate
# ======================================================================
# FALSE NEGATIVES - Hate predicted as Non-Hate
# ======================================================================
#                                                    text actual predicted
# 4344          uta neeru kodbedi aaga kannada barutthe??   Hate  Non-Hate
# 1053  E movie nodudre yare agirli rakhta kudiyuthe p...   Hate  Non-Hate
# 2383  Avanu chai mare gottilla vadhare neenu hudigiy...   Hate  Non-Hate
# 4301                     Sariyagi kaydre currect agtale   Hate  Non-Hate
# 5877  muduka enu gottilde matadodu tappu. Hindu dhar...   Hate  Non-Hate
# 1800           Lo mudeya avarava ooralli avaray gelodhu   Hate  Non-Hate
# 1182  Papa hdk kumaraswamy avanige bari 1kg mutton t...   Hate  Non-Hate
# 3461                                       Hindu virodi   Hate  Non-Hate
# 1124  Kangres gorment barbeku sidramyyasar cmagbeku ...   Hate  Non-Hate
# 2729  Swami , avaga yav govt ittu annodu heltiyalla....   Hate  Non-Hate
# 1577  Le pratham cinema nododu avarice bittidu ninu ...   Hate  Non-Hate
# 2348                                   Oddhu olage haki   Hate  Non-Hate
# 1691                                 Oyo room yali ayti   Hate  Non-Hate
# 3194  Guru neeven gu gambir gu kobu jaste ede naveen...   Hate  Non-Hate
# 191       Sonu loss agide ataaa anisute vaaa nayi marre   Hate  Non-Hate
# 5391        Few media propoganda leader tara adodu bidi   Hate  Non-Hate
# 1462                cheat madi madine melakke ertiddare   Hate  Non-Hate
# 4732                              Godi media modi gedia   Hate  Non-Hate
# 5563  Avalge nam kiccha boss matadidu English sulle ...   Hate  Non-Hate
# 4622  idnyako matheeyathe anthiya bo- magne.. idu av...   Hate  Non-Hate

# %%
# ============================================================
# TASK A - FINAL PREDICTION ON OFFICIAL VALIDATION INPUTS
# ============================================================

from sklearn.base import clone

# ------------------------------------------------------------
# 1. Prepare ALL labeled Task A training data
# ------------------------------------------------------------

X_a_full = binary_train["Comment"]
y_a_full = binary_train["Label"]

print(f"Training samples  : {len(X_a_full)}")
print(f"Prediction samples: {len(binary_val)}")

# ------------------------------------------------------------
# 2. Clone the best Character TF-IDF + Linear SVM model
# ------------------------------------------------------------

final_task_a_model = clone(task_a_char_svm)

# Train on ALL labeled samples
final_task_a_model.fit(X_a_full, y_a_full)

print("\nFinal Task A model trained successfully.")

# ------------------------------------------------------------
# 3. Predict official validation inputs
# ------------------------------------------------------------

y_a_final_pred = final_task_a_model.predict(
    binary_val["Comment"]
)

print(f"Predictions generated: {len(y_a_final_pred)}")

# ------------------------------------------------------------
# 4. Create final prediction file
# ------------------------------------------------------------

task_a_prediction = pd.DataFrame({
    "id": binary_val["id"],
    "label": y_a_final_pred
})

# ------------------------------------------------------------
# 5. Save
# ------------------------------------------------------------

output_path = DATA_DIR / "Task_A_predict.csv"

task_a_prediction.to_csv(
    output_path,
    index=False,
    encoding="utf-8"
)

# ------------------------------------------------------------
# 6. Verify format
# ------------------------------------------------------------

assert task_a_prediction.columns.tolist() == ["id", "label"]
assert len(task_a_prediction) == len(binary_val)
assert task_a_prediction["id"].equals(binary_val["id"])
assert set(task_a_prediction["label"]).issubset({"Hate", "Non-Hate"})

# ------------------------------------------------------------
# 7. Display results
# ------------------------------------------------------------

print("\n" + "=" * 70)
print("TASK A PREDICTION FILE CREATED")
print("=" * 70)

print(f"File: {output_path}")
print(f"Rows: {len(task_a_prediction)}")

print("\nLabel distribution:")
print(task_a_prediction["label"].value_counts())

print("\nFirst 10 predictions:")
display(task_a_prediction.head(10))

print("\n✓ Format verified: id,label")
# Out:
# Training samples  : 6446
# Prediction samples: 806
#
# Final Task A model trained successfully.
# Predictions generated: 806
#
# ======================================================================
# TASK A PREDICTION FILE CREATED
# ======================================================================
# File: S:\4.2\bangla\Hastika-ICON2026\data\Task_A_predict.csv
# Rows: 806
#
# Label distribution:
# label
# Non-Hate    423
# Hate        383
# Name: count, dtype: int64
#
# First 10 predictions:
#      id     label
# 0  4186  Non-Hate
# 1  5693  Non-Hate
# 2  6825  Non-Hate
# 3  1468      Hate
# 4  6361      Hate
# 5  7793      Hate
# 6  5910      Hate
# 7  2380  Non-Hate
# 8  7438  Non-Hate
# 9  6653      Hate
# ✓ Format verified: id,label

# %% [markdown]
# # task B

# %%
from pathlib import Path
import re
import html
import pandas as pd

from sklearn.model_selection import train_test_split

DATA_DIR = Path(r"S:\4.2\bangla\Hastika-ICON2026\data")

multiclass_train = pd.read_csv(DATA_DIR / "multiclass_train.csv")
multiclass_val = pd.read_csv(DATA_DIR / "multiclass_validation_inputs.csv")


def fix_mojibake(text):
    try:
        return text.encode("latin1").decode("utf-8")
    except (UnicodeEncodeError, UnicodeDecodeError):
        return text


def clean_text(text):
    text = fix_mojibake(str(text))
    text = html.unescape(text)
    text = re.sub(r"<[^>]+>", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


multiclass_train["text"] = multiclass_train["Comment"].apply(clean_text)
multiclass_val["text"] = multiclass_val["Comment"].apply(clean_text)

X = multiclass_train["text"]
y = multiclass_train["Hate Category"]

X_train, X_dev, y_train, y_dev = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training:", len(X_train))
print("Development:", len(X_dev))
print("\nClass distribution:")
print(y_train.value_counts())
# Out:
# Training: 2527
# Development: 632
#
# Class distribution:
# Hate Category
# Gender           1089
# Political         447
# Others            359
# Religion          306
# Violence          177
# Geo-political     149
# Name: count, dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# Class weights
balanced_weights = {
    "Gender": 0.3867,
    "Geo-political": 2.8266,
    "Others": 1.1732 * 1.30,
    "Political": 0.9422,
    "Religion": 1.3764,
    "Violence": 2.3795
}

# Character-boundary model
char_wb_model = Pipeline([
    ("tfidf", TfidfVectorizer(
        analyzer="char_wb",
        ngram_range=(2, 5),
        min_df=1,
        sublinear_tf=True,
        max_features=100000
    )),
    ("classifier", LinearSVC(
        C=0.25,
        class_weight=balanced_weights,
        max_iter=10000,
        random_state=42
    ))
])

# Word model
word_model = Pipeline([
    ("tfidf", TfidfVectorizer(
        analyzer="word",
        ngram_range=(1, 3),
        min_df=1,
        sublinear_tf=True,
        max_features=100000
    )),
    ("classifier", LinearSVC(
        C=0.25,
        class_weight=balanced_weights,
        max_iter=10000,
        random_state=42
    ))
])

char_wb_model.fit(X_train, y_train)
word_model.fit(X_train, y_train)

print("Models trained successfully.")
# Out:
# Models trained successfully.

# %%
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)
import matplotlib.pyplot as plt

scores_char = char_wb_model.decision_function(X_dev)
scores_word = word_model.decision_function(X_dev)

# 85% Char-WB + 15% Word
ensemble_scores = (
    0.85 * scores_char +
    0.15 * scores_word
)

# Small decision-score bias found during development
classes = char_wb_model.classes_

ensemble_scores[:, list(classes).index("Others")] += 0.05
ensemble_scores[:, list(classes).index("Violence")] += 0.05

y_pred = classes[np.argmax(ensemble_scores, axis=1)]

accuracy = accuracy_score(y_dev, y_pred)
macro_f1 = f1_score(y_dev, y_pred, average="macro")

print(f"Accuracy : {accuracy:.4f}")
print(f"Macro-F1 : {macro_f1:.4f}")

print("\nClassification Report:")
print(classification_report(y_dev, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_dev, y_pred))

ConfusionMatrixDisplay.from_predictions(
    y_dev,
    y_pred,
    xticks_rotation=45
)

plt.tight_layout()
plt.show()
# Out:
# Accuracy : 0.7199
# Macro-F1 : 0.6460
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Gender       0.80      0.85      0.82       273
# Geo-political       0.65      0.65      0.65        37
#        Others       0.48      0.53      0.51        90
#     Political       0.83      0.74      0.78       112
#      Religion       0.71      0.71      0.71        76
#      Violence       0.50      0.34      0.41        44
#
#      accuracy                           0.72       632
#     macro avg       0.66      0.64      0.65       632
#  weighted avg       0.72      0.72      0.72       632
#
#
# Confusion Matrix:
# [[231   3  26   5   6   2]
#  [  4  24   3   2   3   1]
#  [ 29   2  48   3   3   5]
#  [  8   2  11  83   5   3]
#  [  4   2   6   6  54   4]
#  [ 14   4   5   1   5  15]]

# %%
X_full = multiclass_train["text"]
y_full = multiclass_train["Hate Category"]

final_char_wb = Pipeline([
    ("tfidf", TfidfVectorizer(
        analyzer="char_wb",
        ngram_range=(2, 5),
        min_df=1,
        sublinear_tf=True,
        max_features=100000
    )),
    ("classifier", LinearSVC(
        C=0.25,
        class_weight=balanced_weights,
        max_iter=10000,
        random_state=42
    ))
])

final_word = Pipeline([
    ("tfidf", TfidfVectorizer(
        analyzer="word",
        ngram_range=(1, 3),
        min_df=1,
        sublinear_tf=True,
        max_features=100000
    )),
    ("classifier", LinearSVC(
        C=0.25,
        class_weight=balanced_weights,
        max_iter=10000,
        random_state=42
    ))
])

final_char_wb.fit(X_full, y_full)
final_word.fit(X_full, y_full)

print("Final models trained on all Task B training data.")
# Out:
# Final models trained on all Task B training data.

# %%
official_text = multiclass_val["text"]

scores_char = final_char_wb.decision_function(official_text)
scores_word = final_word.decision_function(official_text)

final_scores = (
    0.85 * scores_char +
    0.15 * scores_word
)

classes = final_char_wb.classes_

final_scores[:, list(classes).index("Others")] += 0.05
final_scores[:, list(classes).index("Violence")] += 0.05

final_predictions = classes[np.argmax(final_scores, axis=1)]

submission = pd.DataFrame({
    "id": multiclass_val["id"],
    "label": final_predictions
})

submission_path = Path(
    r"S:\4.2\bangla\Hastika-ICON2026\submissions\task_b_predictions.csv"
)

submission.to_csv(
    submission_path,
    index=False,
    encoding="utf-8"
)

print(f"Saved: {submission_path}")
print("\nPrediction distribution:")
print(submission["label"].value_counts())

submission.head()
# Out:
# Saved: S:\4.2\bangla\Hastika-ICON2026\submissions\task_b_predictions.csv
#
# Prediction distribution:
# label
# Gender           197
# Political         66
# Others            59
# Religion          45
# Geo-political     20
# Violence           8
# Name: count, dtype: int64
#      id      label
# 0  4204  Political
# 1  6264     Others
# 2  5274     Gender
# 3   391     Gender
# 4  4289     Others

# %%
# ============================================================
# TASK B - FINAL PREDICTION FILE
# ============================================================

from pathlib import Path
import pandas as pd
import numpy as np

# ------------------------------------------------------------
# 1. Official Task B input data
# ------------------------------------------------------------

official_text = multiclass_val["text"]

print(f"Official prediction samples: {len(official_text)}")

# ------------------------------------------------------------
# 2. Get decision scores from both final models
# ------------------------------------------------------------

scores_char = final_char_wb.decision_function(official_text)
scores_word = final_word.decision_function(official_text)

# ------------------------------------------------------------
# 3. 85% Character-WB + 15% Word ensemble
# ------------------------------------------------------------

final_scores = (
    0.85 * scores_char +
    0.15 * scores_word
)

# ------------------------------------------------------------
# 4. Apply the development-time decision-score biases
# ------------------------------------------------------------

classes = final_char_wb.classes_

final_scores[:, list(classes).index("Others")] += 0.05
final_scores[:, list(classes).index("Violence")] += 0.05

# ------------------------------------------------------------
# 5. Generate final predictions
# ------------------------------------------------------------

final_predictions = classes[np.argmax(final_scores, axis=1)]

# ------------------------------------------------------------
# 6. Create submission dataframe
# ------------------------------------------------------------

task_b_prediction = pd.DataFrame({
    "id": multiclass_val["id"],
    "label": final_predictions
})

# ------------------------------------------------------------
# 7. Save prediction file
# ------------------------------------------------------------

output_path = DATA_DIR / "task_b_prediction.csv"

task_b_prediction.to_csv(
    output_path,
    index=False,
    encoding="utf-8"
)

# ------------------------------------------------------------
# 8. Verify submission format
# ------------------------------------------------------------

assert task_b_prediction.columns.tolist() == ["id", "label"]
assert len(task_b_prediction) == len(multiclass_val)
assert task_b_prediction["id"].equals(multiclass_val["id"])

expected_labels = {
    "Gender",
    "Geo-political",
    "Others",
    "Political",
    "Religion",
    "Violence"
}

assert set(task_b_prediction["label"]).issubset(expected_labels)

# ------------------------------------------------------------
# 9. Display results
# ------------------------------------------------------------

print("\n" + "=" * 70)
print("TASK B PREDICTION FILE CREATED")
print("=" * 70)

print(f"File : {output_path}")
print(f"Rows : {len(task_b_prediction)}")

print("\nPrediction distribution:")
print(task_b_prediction["label"].value_counts())

print("\nFirst 10 predictions:")
display(task_b_prediction.head(10))

print("\n✓ Submission format verified!")
# Out:
# Official prediction samples: 395
#
# ======================================================================
# TASK B PREDICTION FILE CREATED
# ======================================================================
# File : S:\4.2\bangla\Hastika-ICON2026\data\task_b_prediction.csv
# Rows : 395
#
# Prediction distribution:
# label
# Gender           197
# Political         66
# Others            59
# Religion          45
# Geo-political     20
# Violence           8
# Name: count, dtype: int64
#
# First 10 predictions:
#      id      label
# 0  4204  Political
# 1  6264     Others
# 2  5274     Gender
# 3   391     Gender
# 4  4289     Others
# 5  2404     Others
# 6  2513     Gender
# 7   504     Gender
# 8   449     Gender
# 9  2357   Religion
# ✓ Submission format verified!
